# %% [markdown]
# These are the tables used in the curated layer of our pipeline ("silver layer", in medallion terms).
#
# The merge tables are overwritten in each import batch and then upserted into the 'real' tables through the merge Python function.

# %%
import duckdb

# %%
con = duckdb.connect('/workspace/data/pipeline.duckdb')
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 con = duckdb.connect('/workspace/data/pipeline.duckdb')
#
# IOException: IO Error: Could not set lock on file "/workspace/data/pipeline.duckdb": Conflicting lock is held in /usr/local/bin/python3.11 (PID 3701). See also https://duckdb.org/docs/stable/connect/concurrency

# %%
con.execute("CREATE SCHEMA IF NOT EXISTS curated")

# %%
con.execute(""" 
            CREATE OR REPLACE TABLE curated.anime(
            raw_id INTEGER NOT NULL,
            batch_id INTEGER,
            page INTEGER,
            anime_id INTEGER PRIMARY KEY,
            title STRING,
            title_english STRING,
            type STRING,
            source STRING,
            no_of_episodes INTEGER,
            status STRING,
            duration STRING,
            score FLOAT,
            scored_by INTEGER,
            rank INTEGER,
            popularity INTEGER,
            members INTEGER,
            favorites INTEGER,
            year INTEGER,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
            """)

con.execute(""" 
            CREATE OR REPLACE TABLE curated.anime_merge(
            raw_id INTEGER NOT NULL,
            batch_id INTEGER,
            page INTEGER,
            anime_id INTEGER PRIMARY KEY,
            title STRING,
            title_english STRING,
            type STRING,
            source STRING,
            no_of_episodes INTEGER,
            status STRING,
            duration STRING,
            score FLOAT,
            scored_by INTEGER,
            rank INTEGER,
            popularity INTEGER,
            members INTEGER,
            favorites INTEGER,
            year INTEGER,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
            """)

# %%
con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_genres(
            anime_id INTEGER,
            genre_id INTEGER,
            genre_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, genre_id)
            )
            """)

con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_genres_merge(
            anime_id INTEGER,
            genre_id INTEGER,
            genre_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, genre_id)
            )
            """)

# %%
con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_themes(
            anime_id INTEGER,
            theme_id INTEGER,
            theme_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, theme_id)
            )
            """)

con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_themes_merge(
            anime_id INTEGER,
            theme_id INTEGER,
            theme_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, theme_id)
            )
            """)

# %%
con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_demographics(
            anime_id INTEGER,
            demographic_id INTEGER,
            demographic_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, demographic_id)
            )
            """)

con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_demographics_merge(
            anime_id INTEGER,
            demographic_id INTEGER,
            demographic_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, demographic_id)
            )
            """)

# %%
con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_studios(
            anime_id INTEGER,
            studio_id INTEGER,
            studio_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, studio_id)
            )
            """)

con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_studios_merge(
            anime_id INTEGER,
            studio_id INTEGER,
            studio_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, studio_id)
            )
            """)

# %%
con.execute("""
            CREATE OR REPLACE TABLE curated.links_anime_producers(
            anime_id INTEGER,
            producer_id INTEGER,
            producer_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, producer_id)
            )
            """)

con.execute("""
            CREATE OR REPLACE TABLE curated.links_anime_producers_merge(
            anime_id INTEGER,
            producer_id INTEGER,
            producer_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, producer_id)
            )
            """)

# %%
con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_licensors(
            anime_id INTEGER,
            licensor_id INTEGER,
            licensor_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, licensor_id)
            )
            """)

con.execute(""" 
            CREATE OR REPLACE TABLE curated.links_anime_licensors_merge(
            anime_id INTEGER,
            licensor_id INTEGER,
            licensor_name STRING,
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            PRIMARY KEY (anime_id, licensor_id)
            )
            """)

# %%
con.close()
