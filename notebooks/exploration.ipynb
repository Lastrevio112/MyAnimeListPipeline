# %%
import duckdb
import pandas as pd
#Connect to DuckDB
con = duckdb.connect('/workspace/data/pipeline.duckdb')
print('Connected to DuckDB!)

# %%
con.execute(\"SHOW ALL TABLES\").df()

# %%
con.execute(\"SELECT * FROM raw.raw_orders LIMIT 10\").df()
